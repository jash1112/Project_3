# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
# Make a reference 
csv_path = Path("csv/Project 3 Data.csv")

# Import as a DataFrame
G20 = pd.read_csv(csv_path, encoding = "utf-8")



# Rename colums

G20
# Out:
#                               Company_Name    Country    Market_Cap  \
# 0                            Microsoft DRC  Argentina  2.557400e+09
# 1                                Apple DRC  Argentina  2.364020e+09
# 2                                   NVIDIA  Argentina  1.627070e+09
# 3                                 Broadcom  Argentina  5.124900e+08
# 4    Taiwan Semiconductor Manufacturing Co  Argentina  4.801000e+08
# ..                                     ...        ...           ...
# 186                               Infineon         EU  4.315000e+04
# 187                     STMicroelectronics         EU  3.750000e+04
# 188                     STMicroelectronics         EU  3.750000e+04
# 189                                 Orange         EU  2.854000e+04
# 190                                Amadeus         EU  2.676000e+04
#
#      P/E_Ratio  Dividend
# 0        36.97      0.10
# 1        28.31      0.03
# 2        65.68      0.00
# 3        34.55      0.34
# ...

# %%
# Finding unique countries

G20_countries = G20['Country'].unique()

G20_countries
# Out:
# array(['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
#        'Germany', 'India', 'Indonesia', 'Italy', 'Japan', 'Mexico',
#        'Russia', 'Saudi Arabia', 'South Korea', 'Turkey',
#        'United Kingdom', 'USA', 'EU'], dtype=object)

# %%
# Create a DataFrame for Argentina

argentina_data = G20[G20['Country'] == 'Argentina']

# Display the DataFrame

argentina_data
# Out:
#                             Company_Name    Country    Market_Cap  P/E_Ratio  \
# 0                          Microsoft DRC  Argentina  2.557400e+09      36.97
# 1                              Apple DRC  Argentina  2.364020e+09      28.31
# 2                                 NVIDIA  Argentina  1.627070e+09      65.68
# 3                               Broadcom  Argentina  5.124900e+08      34.55
# 4  Taiwan Semiconductor Manufacturing Co  Argentina  4.801000e+08      19.98
# 5                                   Visa  Argentina  4.782200e+08      32.69
# 6                             Mastercard  Argentina  3.690700e+08      39.57
# 7                                 Oracle  Argentina  2.580100e+08      30.05
# 8                             SAP SE DRC  Argentina  1.793700e+08      32.42
# 9                      Cisco Systems DRC  Argentina  1.659400e+08      14.86
#
#    Dividend
# 0      0.10
# 1      0.03
# 2      0.00
# 3      0.34
# 4      0.19
# 5      0.12
# 6      0.08
# 7      0.34
# ...

# %%
# Create a DataFrame for 

australia_data = G20[G20['Country'] == 'Australia']

# Display the DataFrame

australia_data
# Out:
#          Company_Name    Country  Market_Cap  P/E_Ratio  Dividend
# 10      Telstra Group  Australia     44720.0      21.99      0.17
# 11    Wisetech Global  Australia     29090.0     130.10      0.16
# 12          Rea Group  Australia     24760.0      87.67      1.70
# 13       Carsales.Com  Australia     13330.0      37.60      0.67
# 14  Spark New Zealand  Australia      8830.0       8.50      0.32
# 15             Altium  Australia      8650.0      85.49      0.54
# 16     Technology One  Australia      5410.0      52.40      0.20
# 17             Chorus  Australia      3240.0     140.71      0.42
# 18        Dicker Data  Australia      2170.0      28.13      0.45
# 19   Domain Australia  Australia      2090.0      56.90      0.06

# %%
# Create a DataFrame for 

brazil_data = G20[G20['Country'] == 'Brazil']

# Display the DataFrame

brazil_data
# Out:
#                              Company_Name Country  Market_Cap  P/E_Ratio  \
# 20                     Microsoft Corp BDR  Brazil  15230000.0      36.97
# 21                          Apple Inc BDR  Brazil  14080000.0      28.31
# 22                                 Nvidia  Brazil   9640000.0      63.42
# 23                               Broadcom  Brazil   3040000.0      34.55
# 24  Taiwan Semiconductor Manufacturing Co  Brazil   2850000.0      19.98
# 25                           Visa Inc BDR  Brazil   2850000.0      32.69
# 26                     MasterCard Inc BDR  Brazil   2210000.0      39.95
# 27                        ASML Holding NV  Brazil   1840000.0      41.93
# 28                        Oracle Corp BDR  Brazil   1540000.0      30.05
# 29                  Cisco Systems Inc BDR  Brazil    988190.0      14.86
#
#     Dividend
# 20      0.41
# 21      0.16
# 22      0.01
# 23      1.00
# 24      0.92
# 25      0.34
# 26      0.28
# 27      0.48
# 28      0.87
# 29      1.08

# %%
# Create a DataFrame for Canada

canada_data = G20[G20['Country'] == 'Canada']

# Display the DataFrame

canada_data

# %%
# Create a DataFrame for China

china_data = G20[G20['Country'] == 'China']

# Display the DataFrame

china_data

# %%
# Create a DataFrame for France

france_data = G20[G20['Country'] == 'France']

# Display the DataFrame

france_data

# %%
# Create a DataFrame for Germany

germany_data = G20[G20['Country'] == 'Germany']

# Display the DataFrame

germany_data

# %%
# Create a DataFrame for India

india_data = G20[G20['Country'] == 'India']

# Display the DataFrame

india_data

# %%
# Create a DataFrame for Indonesia

indonesia_data = G20[G20['Country'] == 'Indonesia']

# Display the DataFrame

indonesia_data

# %%
# Create a DataFrame for Italy

italy_data = G20[G20['Country'] == 'Italy']

# Display the DataFrame

italy_data

# %%
# Create a DataFrame for Japan

japan_data = G20[G20['Country'] == 'Japan']

# Display the DataFrame

japan_data

# %%
# Create a DataFrame for Mexico

mexico_data = G20[G20['Country'] == 'Mexico']

# Display the DataFrame

mexico_data

# %%
# Create a DataFrame for Russia

russia_data = G20[G20['Country'] == 'Russia']

# Display the DataFrame

russia_data

# %%
# Create a DataFrame for Saudi Arabia

saudi_arabia_data = G20[G20['Country'] == 'Saudi Arabia']

# Display the DataFrame

saudi_arabia_data

# %%
# Create a DataFrame for 

south_korea_data = G20[G20['Country'] == 'South Korea']

# Display the DataFrame

_data

# %%
# Create a DataFrame for 

_data = G20[G20['Country'] == 'Turkey']

# Display the DataFrame

_data

# %%
# Create a DataFrame for 

_data = G20[G20['Country'] == 'United Kingdom']

# Display the DataFrame

_data

# %%
# Create a DataFrame for 

_data = G20[G20['Country'] == 'USA']

# Display the DataFrame

_data

# %%
# Create a DataFrame for 

_data = G20[G20['Country'] == 'EU']

# Display the DataFrame

_data
